# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#total training data
train_data = X_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7595     -118.25     33.90                38.0       1201.0           223.0
# 11507    -118.09     33.74                44.0       1671.0           390.0
# 7299     -118.20     33.99                35.0       1705.0           523.0
# 10744    -117.92     33.61                36.0       1025.0           150.0
# 16506    -121.13     37.73                40.0       1126.0           220.0
# ...          ...       ...                 ...          ...             ...
# 9599     -120.50     37.31                36.0       2162.0           433.0
# 8988     -118.36     33.99                35.0       3702.0           648.0
# 11916    -117.40     33.95                32.0       1979.0           491.0
# 8577     -118.41     33.89                31.0       1428.0           320.0
# 1558     -121.94     37.80                 8.0      11336.0          1657.0
#
#        population  households  median_income ocean_proximity  \
# 7595        733.0       206.0         3.3804       <1H OCEAN
# 11507       871.0       367.0         4.6369      NEAR OCEAN
# 7299       2252.0       508.0         2.3421       <1H OCEAN
# 10744       316.0       126.0        10.3048       <1H OCEAN
# 16506       667.0       235.0         3.3158          INLAND
# ...           ...         ...            ...             ...
# 9599       1048.0       451.0         2.6797          INLAND
# 8988       1449.0       614.0         5.3194       <1H OCEAN
# 11916       954.0       444.0         2.4408          INLAND
# 8577        677.0       331.0         7.2316       <1H OCEAN
# 1558       4089.0      1555.0         7.8287       <1H OCEAN
#
#        median_house_value
# 7595             105800.0
# 11507            422200.0
# 7299             154200.0
# 10744            500001.0
# 16506            125900.0
# ...                   ...
# 9599              81800.0
# 8988             313700.0
# 11916            117300.0
# 8577             500001.0
# 1558             369200.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# to make the histograms look more like normal distribution
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#hot encoding Ocean Proximity
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7182
# INLAND        5214
# NEAR OCEAN    2124
# NEAR BAY      1822
# ISLAND           4
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity, dtype=int)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 7595           1       0       0         0           0
# 11507          0       0       0         0           1
# 7299           1       0       0         0           0
# 10744          1       0       0         0           0
# 16506          0       1       0         0           0
# ...          ...     ...     ...       ...         ...
# 9599           0       1       0         0           0
# 8988           1       0       0         0           0
# 11916          0       1       0         0           0
# 8577           1       0       0         0           0
# 1558           1       0       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data.join(pd.get_dummies(train_data.ocean_proximity, dtype=int))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
#
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 7595        0       0         0           0
# 11507       0       0         0           1
# 7299        0       0         0           0
# 10744       0       0         0           0
# 16506       1       0         0           0
# ...       ...     ...       ...         ...
# 9599        1       0         0           0
# 8988        0       0         0           0
# 11916       1       0         0           0
# 8577        0       0         0           0
# 1558        0       0         0           0
#
# [16346 rows x 14 columns]

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925185           -0.109674     0.034736
# latitude            -0.925185  1.000000            0.011934    -0.036871
# housing_median_age  -0.109674  0.011934            1.000000    -0.312377
# total_rooms          0.034736 -0.036871           -0.312377     1.000000
# total_bedrooms       0.065889 -0.073150           -0.269086     0.944822
# population           0.114671 -0.142263           -0.238695     0.863216
# households           0.060230 -0.092154           -0.238076     0.930510
# median_income       -0.016630 -0.077737           -0.122892     0.202699
# median_house_value  -0.046173 -0.143098            0.104871     0.162339
# <1H OCEAN            0.316124 -0.442382            0.042539     0.018287
# INLAND              -0.054789  0.350229           -0.239069    -0.012246
# ISLAND               0.009704 -0.016773            0.021142    -0.003937
# NEAR BAY            -0.476197  0.360107            0.262104    -0.015163
# NEAR OCEAN           0.054576 -0.168754            0.022294     0.004357
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.065889    0.114671    0.060230      -0.016630
# latitude                 -0.073150   -0.142263   -0.092154      -0.077737
# housing_median_age       -0.269086   -0.238695   -0.238076      -0.122892
# total_rooms               0.944822    0.863216    0.930510       0.202699
# total_bedrooms            1.000000    0.896398    0.974358      -0.030971
# population                0.896398    1.000000    0.931561      -0.009123
# households                0.974358    0.931561    1.000000      -0.001583
# median_income            -0.030971   -0.009123   -0.001583       1.000000
# median_house_value        0.056700   -0.019361    0.075349       0.686459
# <1H OCEAN                 0.038498    0.113902    0.069345       0.170299
# INLAND                   -0.044935   -0.071842   -0.086739      -0.236751
# ISLAND                    0.001331   -0.010880   -0.007091      -0.008946
# NEAR BAY                 -0.014744   -0.058399   -0.003321       0.055729
# NEAR OCEAN                0.019199   -0.013377    0.021314       0.025058
#
#                     median_house_value  <1H OCEAN    INLAND    ISLAND  \
# longitude                    -0.046173   0.316124 -0.054789  0.009704
# latitude                     -0.143098  -0.442382  0.350229 -0.016773
# housing_median_age            0.104871   0.042539 -0.239069  0.021142
# total_rooms                   0.162339   0.018287 -0.012246 -0.003937
# total_bedrooms                0.056700   0.038498 -0.044935  0.001331
# population                   -0.019361   0.113902 -0.071842 -0.010880
# households                    0.075349   0.069345 -0.086739 -0.007091
# median_income                 0.686459   0.170299 -0.236751 -0.008946
# median_house_value            1.000000   0.257536 -0.484146  0.026625
# <1H OCEAN                     0.257536   1.000000 -0.605869 -0.013850
# INLAND                       -0.484146  -0.605869  1.000000 -0.010707
# ISLAND                        0.026625  -0.013850 -0.010707  1.000000
# NEAR BAY                      0.161228  -0.313553 -0.242399 -0.005541
# NEAR OCEAN                    0.138821  -0.342119 -0.264482 -0.006046
#
#                     NEAR BAY  NEAR OCEAN
# longitude          -0.476197    0.054576
# latitude            0.360107   -0.168754
# housing_median_age  0.262104    0.022294
# total_rooms        -0.015163    0.004357
# total_bedrooms     -0.014744    0.019199
# population         -0.058399   -0.013377
# households         -0.003321    0.021314
# median_income       0.055729    0.025058
# median_house_value  0.161228    0.138821
# <1H OCEAN          -0.313553   -0.342119
# INLAND             -0.242399   -0.264482
# ISLAND             -0.005541   -0.006046
# NEAR BAY            1.000000   -0.136876
# NEAR OCEAN         -0.136876    1.000000

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
# Adding new features
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']      #total bedrooms per rooms
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']        #no. of rooms per household

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

X_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']

reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity, dtype=int)).drop(['ocean_proximity'], axis=1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1981     -120.84     38.63                12.0     7.180831        5.446737
# 13183    -117.70     33.92                 4.0     9.024252        7.195937
# 9398     -122.55     37.90                34.0     7.266827        5.416100
# 10488    -117.68     33.49                16.0     8.034307        6.586172
# 19632    -120.85     37.55                45.0     5.860786        4.143135
# ...          ...       ...                 ...          ...             ...
# 12067    -117.58     33.85                 6.0     9.706986        7.878913
# 16899    -122.34     37.59                44.0     7.241366        5.598422
# 19593    -120.87     37.60                32.0     8.429454        6.818924
# 10807    -117.93     33.65                35.0     7.665753        6.025866
# 18108    -122.00     37.31                28.0     8.245909        6.373320
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 1981     6.595781    5.451038         5.7373            208300.0          0
# 13183    8.279443    7.120444         6.2141            252200.0          1
# 9398     6.222576    5.398163         7.9606            453400.0          0
# 10488    7.846981    6.538140         2.8357            106300.0          1
# 19632    5.236442    4.158883         2.5938            275000.0          0
# ...           ...         ...            ...                 ...        ...
# 12067    9.014690    7.845416         5.2861            195100.0          0
# 16899    6.602588    5.666427         5.6206            386400.0          0
# 19593    7.916807    6.753438         2.6619             86200.0          0
# 10807    7.295735    5.998937         4.4211            215200.0          1
# 18108    7.493317    6.366470         7.8383            372700.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 1981        1       0         0           0       0.758511         1.317333
# 13183       0       0         0           0       0.797400         1.267372
# 9398        0       0         1           0       0.745318         1.346167
# 10488       0       0         0           0       0.819756         1.228837
# 19632       1       0         0           0       0.706925         1.409221
# ...       ...     ...       ...         ...            ...              ...
# 12067       1       0         0           0       0.811674         1.237281
# 16899       0       0         0           1       0.773117         1.277942
# 19593       1       0         0           0       0.808940         1.248172
# 10807       0       0         0           0       0.786076         1.277852
# 18108       0       0         0           0       0.772907         1.295209
#
# [4087 rows x 16 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7595     -118.25     33.90                38.0     7.091742        5.411646
# 11507    -118.09     33.74                44.0     7.421776        5.968708
# 7299     -118.20     33.99                35.0     7.441907        6.261492
# 10744    -117.92     33.61                36.0     6.933423        5.017280
# 16506    -121.13     37.73                40.0     7.027315        5.398163
# ...          ...       ...                 ...          ...             ...
# 9599     -120.50     37.31                36.0     7.679251        6.073045
# 8988     -118.36     33.99                35.0     8.216899        6.475433
# 11916    -117.40     33.95                32.0     7.590852        6.198479
# 8577     -118.41     33.89                31.0     7.264730        5.771441
# 1558     -121.94     37.80                 8.0     9.335827        7.413367
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 7595     6.598509    5.332719         3.3804            105800.0          1
# 11507    6.770789    5.908083         4.6369            422200.0          0
# 7299     7.720018    6.232448         2.3421            154200.0          1
# 10744    5.758902    4.844187        10.3048            500001.0          1
# 16506    6.504288    5.463832         3.3158            125900.0          0
# ...           ...         ...            ...                 ...        ...
# 9599     6.955593    6.113682         2.6797             81800.0          0
# 8988     7.279319    6.421622         5.3194            313700.0          1
# 11916    6.861711    6.098074         2.4408            117300.0          0
# 8577     6.519147    5.805135         7.2316            500001.0          1
# 1558     8.316300    7.349874         7.8287            369200.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 7595        0       0         0           0       0.763091         1.329855
# 11507       0       0         0           1       0.804216         1.256207
# 7299        0       0         0           0       0.841383         1.194058
# 10744       0       0         0           0       0.723637         1.431287
# 16506       1       0         0           0       0.768169         1.286151
# ...       ...     ...       ...         ...            ...              ...
# 9599        1       0         0           0       0.790838         1.256076
# 8988        0       0         0           0       0.788063         1.279567
# 11916       1       0         0           0       0.816572         1.244795
# 8577        0       0         0           0       0.794447         1.251432
# 1558        0       0         0           0       0.794077         1.270202
#
# [16346 rows x 16 columns]

# %%
X_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
reg.score(X_test, y_test)
# Out:
# 0.6735040259022513

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.8144177223071823
